# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import glob

# %%
path = 'Labeld/'
# choose a random file
flist = glob.glob(path+'*.xml').split('\\')
flist = [fullname.split('\\')[1] for fullname in flist]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-53a43f9a50ee> in <module>()
#       1 path = 'Labeld/'
#       2 # choose a random file
# ----> 3 flist = glob.glob(path+'*.xml').split('\\')[-1]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
flist
# Out:
# ['Labeld\\IMG_0003.xml',
#  'Labeld\\IMG_0008.xml',
#  'Labeld\\IMG_0009.xml',
#  'Labeld\\IMG_0012.xml',
#  'Labeld\\IMG_0013.xml',
#  'Labeld\\IMG_0016.xml',
#  'Labeld\\IMG_0019.xml',
#  'Labeld\\IMG_0022.xml',
#  'Labeld\\IMG_0026.xml',
#  'Labeld\\IMG_0028.xml',
#  'Labeld\\IMG_0032.xml',
#  'Labeld\\IMG_0036.xml',
#  'Labeld\\IMG_0039.xml',
#  'Labeld\\IMG_0044.xml',
#  'Labeld\\IMG_0047.xml',
#  'Labeld\\IMG_0050.xml',
#  'Labeld\\IMG_0054.xml',
#  'Labeld\\IMG_0056.xml',
#  'Labeld\\IMG_0064.xml',
#  'Labeld\\IMG_0068.xml',
#  'Labeld\\IMG_0071.xml',
#  'Labeld\\IMG_0076.xml',
#  'Labeld\\IMG_0079.xml',
#  'Labeld\\IMG_0082.xml',
#  'Labeld\\IMG_0085.xml',
#  'Labeld\\IMG_0088.xml',
#  'Labeld\\IMG_0091.xml',
#  'Labeld\\IMG_0093.xml',
#  'Labeld\\IMG_0096.xml',
#  'Labeld\\IMG_0099.xml',
#  'Labeld\\IMG_0102.xml',
#  'Labeld\\IMG_0105.xml',
#  'Labeld\\IMG_0108.xml',
#  'Labeld\\IMG_0111.xml',
#  'Labeld\\IMG_0114.xml',
#  'Labeld\\IMG_0117.xml',
#  'Labeld\\IMG_0120.xml',
# ...
